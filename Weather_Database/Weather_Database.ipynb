# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

#Import the time Module
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 803

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | new norfolk
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | tuktoyaktuk
# Processing Record 6 of Set 1 | dovolnoye
# Processing Record 7 of Set 1 | palmer
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | buala
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | bulgan
# Processing Record 19 of Set 1 | husavik
# Processing Record 20 of Set 1 | malkangiri
# Processing Record 21 of Set 1 | nishihara
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | bela
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | dillon
# Processing Record 26 of Set 1 | iquitos
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | tucupita
# Processing Record 30 of Set 1 | huinan
# Processing Record 31 of Set 1 | quelimane
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | biltine
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | saint george
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | sercaia
# Processing Record 39 of Set 1 | saldanha
# Processing Record 40 of Set 1 | bembereke
# Processing Record 41 of Set 1 | heihe
# Processing Record 42 of Set 1 | alice springs
# Processing Record 43 of Set 1 | la asuncion
# Processing Record 44 of Set 1 | port lincoln
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 1 | kamaishi
# Processing Record 48 of Set 1 | chuy
# Processing Record 49 of Set 1 | fukue
# Processing Record 50 of Set 1 | helong
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | airai
# Processing Record 3 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 2 | grand gaube
# Processing Record 5 of Set 2 | muzhi
# Processing Record 6 of Set 2 | lorengau
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | saskylakh
# Processing Record 9 of Set 2 | chara
# Processing Record 10 of Set 2 | paamiut
# Processing Record 11 of Set 2 | cidreira
# Processing Record 12 of Set 2 | belyy yar
# Processing Record 13 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 2 | punta arenas
# Processing Record 15 of Set 2 | dangriga
# Processing Record 16 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 2 | vestmannaeyjar
# Processing Record 18 of Set 2 | pevek
# Processing Record 19 of Set 2 | maple creek
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | kadykchan
# City not found. Skipping...
# Processing Record 24 of Set 2 | weligama
# Processing Record 25 of Set 2 | ust-tsilma
# Processing Record 26 of Set 2 | saint anthony
# Processing Record 27 of Set 2 | bathsheba
# Processing Record 28 of Set 2 | cordoba
# Processing Record 29 of Set 2 | hammerfest
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | jacmel
# Processing Record 32 of Set 2 | slave lake
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | razgrad
# Processing Record 36 of Set 2 | sawtell
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | luderitz
# Processing Record 39 of Set 2 | arlit
# Processing Record 40 of Set 2 | thiruvarur
# Processing Record 41 of Set 2 | camana
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 2 | mitsamiouli
# Processing Record 45 of Set 2 | sfantu gheorghe
# Processing Record 46 of Set 2 | greensboro
# Processing Record 47 of Set 2 | vila
# Processing Record 48 of Set 2 | usmajac
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | upernavik
# Processing Record 1 of Set 3 | pingliang
# Processing Record 2 of Set 3 | bengkulu
# Processing Record 3 of Set 3 | borovoy
# Processing Record 4 of Set 3 | waddan
# Processing Record 5 of Set 3 | burnie
# Processing Record 6 of Set 3 | khvoynaya
# Processing Record 7 of Set 3 | bitung
# Processing Record 8 of Set 3 | inhambane
# Processing Record 9 of Set 3 | fortuna
# Processing Record 10 of Set 3 | barrow
# Processing Record 11 of Set 3 | borogontsy
# Processing Record 12 of Set 3 | georgetown
# Processing Record 13 of Set 3 | loreto
# Processing Record 14 of Set 3 | dunedin
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | cabo san lucas
# Processing Record 17 of Set 3 | orotukan
# Processing Record 18 of Set 3 | saint-francois
# Processing Record 19 of Set 3 | verkhniy uslon
# Processing Record 20 of Set 3 | lavrentiya
# Processing Record 21 of Set 3 | shulan
# Processing Record 22 of Set 3 | mandalay
# Processing Record 23 of Set 3 | balabac
# Processing Record 24 of Set 3 | luwuk
# Processing Record 25 of Set 3 | chaozhou
# Processing Record 26 of Set 3 | smithers
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | bowen
# Processing Record 29 of Set 3 | norman wells
# Processing Record 30 of Set 3 | gualaceo
# Processing Record 31 of Set 3 | tawau
# Processing Record 32 of Set 3 | hami
# Processing Record 33 of Set 3 | san patricio
# Processing Record 34 of Set 3 | buchanan
# Processing Record 35 of Set 3 | tecoanapa
# Processing Record 36 of Set 3 | buba
# Processing Record 37 of Set 3 | tiksi
# Processing Record 38 of Set 3 | oksfjord
# Processing Record 39 of Set 3 | san cristobal
# Processing Record 40 of Set 3 | alenquer
# Processing Record 41 of Set 3 | micheweni
# Processing Record 42 of Set 3 | dingle
# Processing Record 43 of Set 3 | riyadh
# Processing Record 44 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 3 | clyde river
# Processing Record 47 of Set 3 | lebu
# Processing Record 48 of Set 3 | nosy varika
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 3 | andenes
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | jumla
# Processing Record 3 of Set 4 | kilcullen
# Processing Record 4 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 4 | broken hill
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | narsaq
# Processing Record 9 of Set 4 | bredasdorp
# Processing Record 10 of Set 4 | matara
# Processing Record 11 of Set 4 | dingras
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | laguna
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | itarema
# Processing Record 16 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 4 | saint-philippe
# Processing Record 18 of Set 4 | ballina
# Processing Record 19 of Set 4 | qostanay
# Processing Record 20 of Set 4 | camalu
# Processing Record 21 of Set 4 | ouro preto do oeste
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | gergebil
# Processing Record 24 of Set 4 | kenai
# Processing Record 25 of Set 4 | belmonte
# Processing Record 26 of Set 4 | ostersund
# Processing Record 27 of Set 4 | nuevo progreso
# Processing Record 28 of Set 4 | perisoru
# Processing Record 29 of Set 4 | daru
# Processing Record 30 of Set 4 | carutapera
# Processing Record 31 of Set 4 | the pas
# Processing Record 32 of Set 4 | cayambe
# Processing Record 33 of Set 4 | puerto ayora
# Processing Record 34 of Set 4 | kimbe
# Processing Record 35 of Set 4 | mitchell
# Processing Record 36 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 4 | saint-die
# City not found. Skipping...
# Processing Record 38 of Set 4 | athabasca
# Processing Record 39 of Set 4 | chernyshevskiy
# Processing Record 40 of Set 4 | humberto de campos
# Processing Record 41 of Set 4 | north platte
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | port-cartier
# Processing Record 44 of Set 4 | iguape
# Processing Record 45 of Set 4 | boende
# Processing Record 46 of Set 4 | araouane
# Processing Record 47 of Set 4 | aykhal
# Processing Record 48 of Set 4 | high prairie
# Processing Record 49 of Set 4 | fairbanks
# Processing Record 50 of Set 4 | haines junction
# Processing Record 1 of Set 5 | murray bridge
# Processing Record 2 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 5 | dikson
# Processing Record 4 of Set 5 | tsimlyansk
# Processing Record 5 of Set 5 | przhevalskoye
# Processing Record 6 of Set 5 | felanitx
# Processing Record 7 of Set 5 | salinas
# Processing Record 8 of Set 5 | zapolyarnyy
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | kearney
# Processing Record 11 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 12 of Set 5 | yulara
# Processing Record 13 of Set 5 | warmbad
# Processing Record 14 of Set 5 | mogadishu
# Processing Record 15 of Set 5 | birjand
# Processing Record 16 of Set 5 | san quintin
# Processing Record 17 of Set 5 | osmanabad
# Processing Record 18 of Set 5 | shelburne
# Processing Record 19 of Set 5 | christchurch
# Processing Record 20 of Set 5 | kaniama
# Processing Record 21 of Set 5 | cherskiy
# Processing Record 22 of Set 5 | comodoro rivadavia
# Processing Record 23 of Set 5 | lacombe
# Processing Record 24 of Set 5 | ilulissat
# Processing Record 25 of Set 5 | lac du bonnet
# Processing Record 26 of Set 5 | victoria point
# Processing Record 27 of Set 5 | galveston
# Processing Record 28 of Set 5 | barabash
# Processing Record 29 of Set 5 | krasnokamensk
# Processing Record 30 of Set 5 | padang
# Processing Record 31 of Set 5 | marsa matruh
# Processing Record 32 of Set 5 | chokurdakh
# Processing Record 33 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 34 of Set 5 | bontang
# Processing Record 35 of Set 5 | dhidhdhoo
# Processing Record 36 of Set 5 | clinton
# Processing Record 37 of Set 5 | puerto madero
# Processing Record 38 of Set 5 | goderich
# Processing Record 39 of Set 5 | toora-khem
# Processing Record 40 of Set 5 | unye
# City not found. Skipping...
# Processing Record 41 of Set 5 | rawson
# Processing Record 42 of Set 5 | pingshan
# Processing Record 43 of Set 5 | coihaique
# Processing Record 44 of Set 5 | bambous virieux
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 5 | pryozerne
# Processing Record 49 of Set 5 | lourdes
# Processing Record 50 of Set 5 | hasaki
# Processing Record 1 of Set 6 | kefamenanu
# Processing Record 2 of Set 6 | ahmadpur east
# Processing Record 3 of Set 6 | vardo
# Processing Record 4 of Set 6 | acapulco
# Processing Record 5 of Set 6 | kavaratti
# Processing Record 6 of Set 6 | lahaina
# Processing Record 7 of Set 6 | yerbogachen
# Processing Record 8 of Set 6 | meulaboh
# Processing Record 9 of Set 6 | el porvenir
# Processing Record 10 of Set 6 | rio gallegos
# Processing Record 11 of Set 6 | mana
# Processing Record 12 of Set 6 | ferkessedougou
# Processing Record 13 of Set 6 | sovetskiy
# Processing Record 14 of Set 6 | macau
# Processing Record 15 of Set 6 | lodja
# Processing Record 16 of Set 6 | wanaka
# Processing Record 17 of Set 6 | byron bay
# Processing Record 18 of Set 6 | verkhnyaya inta
# Processing Record 19 of Set 6 | quatre cocos
# Processing Record 20 of Set 6 | russell
# Processing Record 21 of Set 6 | shingu
# Processing Record 22 of Set 6 | tuatapere
# Processing Record 23 of Set 6 | kiunga
# Processing Record 24 of Set 6 | sinnamary
# Processing Record 25 of Set 6 | wilmington
# Processing Record 26 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 6 | tasiilaq
# Processing Record 28 of Set 6 | khani
# Processing Record 29 of Set 6 | dukat
# Processing Record 30 of Set 6 | charlestown
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | srednekolymsk
# Processing Record 33 of Set 6 | brae
# Processing Record 34 of Set 6 | hovd
# Processing Record 35 of Set 6 | alta floresta
# Processing Record 36 of Set 6 | maroantsetra
# Processing Record 37 of Set 6 | quang ngai
# Processing Record 38 of Set 6 | komsomolskiy
# Processing Record 39 of Set 6 | tambura
# Processing Record 40 of Set 6 | calnali
# Processing Record 41 of Set 6 | hambantota
# Processing Record 42 of Set 6 | iqaluit
# Processing Record 43 of Set 6 | menongue
# Processing Record 44 of Set 6 | kashi
# Processing Record 45 of Set 6 | bavleny
# Processing Record 46 of Set 6 | kavieng
# Processing Record 47 of Set 6 | pemba
# Processing Record 48 of Set 6 | geraldton
# Processing Record 49 of Set 6 | newport
# Processing Record 50 of Set 6 | yar-sale
# Processing Record 1 of Set 7 | kununurra
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | kargil
# Processing Record 4 of Set 7 | shitkino
# Processing Record 5 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 7 | swabi
# Processing Record 7 of Set 7 | chama
# Processing Record 8 of Set 7 | liminangcong
# City not found. Skipping...
# Processing Record 9 of Set 7 | udachnyy
# Processing Record 10 of Set 7 | gisborne
# Processing Record 11 of Set 7 | andros town
# Processing Record 12 of Set 7 | nikolskoye
# Processing Record 13 of Set 7 | takoradi
# Processing Record 14 of Set 7 | sembe
# Processing Record 15 of Set 7 | san jeronimo
# Processing Record 16 of Set 7 | ust-kulom
# Processing Record 17 of Set 7 | mehamn
# Processing Record 18 of Set 7 | ndioum
# Processing Record 19 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 7 | oxbow
# Processing Record 22 of Set 7 | kahului
# Processing Record 23 of Set 7 | thompson
# Processing Record 24 of Set 7 | pio xii
# Processing Record 25 of Set 7 | bose
# Processing Record 26 of Set 7 | ojinaga
# Processing Record 27 of Set 7 | chabahar
# Processing Record 28 of Set 7 | padilla
# Processing Record 29 of Set 7 | lata
# Processing Record 30 of Set 7 | umm lajj
# Processing Record 31 of Set 7 | avera
# Processing Record 32 of Set 7 | miri
# Processing Record 33 of Set 7 | mananara
# Processing Record 34 of Set 7 | namie
# Processing Record 35 of Set 7 | mount gambier
# Processing Record 36 of Set 7 | puerto pinasco
# City not found. Skipping...
# Processing Record 37 of Set 7 | nexo
# Processing Record 38 of Set 7 | siguiri
# Processing Record 39 of Set 7 | minab
# Processing Record 40 of Set 7 | alofi
# Processing Record 41 of Set 7 | praia
# Processing Record 42 of Set 7 | taoudenni
# Processing Record 43 of Set 7 | mayo
# Processing Record 44 of Set 7 | san jose
# Processing Record 45 of Set 7 | mendoza
# Processing Record 46 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 7 | yinchuan
# Processing Record 49 of Set 7 | nemuro
# Processing Record 50 of Set 7 | mago
# Processing Record 1 of Set 8 | boa esperanca
# Processing Record 2 of Set 8 | suluq
# Processing Record 3 of Set 8 | guadalupe y calvo
# Processing Record 4 of Set 8 | kieta
# Processing Record 5 of Set 8 | tongliao
# Processing Record 6 of Set 8 | jalu
# Processing Record 7 of Set 8 | santa isabel
# Processing Record 8 of Set 8 | balykshi
# Processing Record 9 of Set 8 | souillac
# Processing Record 10 of Set 8 | mabaruma
# Processing Record 11 of Set 8 | vengerovo
# Processing Record 12 of Set 8 | olafsvik
# Processing Record 13 of Set 8 | santa isabel do rio negro
# Processing Record 14 of Set 8 | guerrero negro
# Processing Record 15 of Set 8 | mahebourg
# Processing Record 16 of Set 8 | tilichiki
# Processing Record 17 of Set 8 | falmouth
# Processing Record 18 of Set 8 | catuday
# Processing Record 19 of Set 8 | lewistown
# Processing Record 20 of Set 8 | svetlyy
# Processing Record 21 of Set 8 | vanavara
# Processing Record 22 of Set 8 | hamilton
# Processing Record 23 of Set 8 | lashio
# Processing Record 24 of Set 8 | olga
# Processing Record 25 of Set 8 | krasnoslobodsk
# Processing Record 26 of Set 8 | saint-alexandre
# Processing Record 27 of Set 8 | corner brook
# Processing Record 28 of Set 8 | bilma
# Processing Record 29 of Set 8 | esperance
# Processing Record 30 of Set 8 | koumac
# Processing Record 31 of Set 8 | ancud
# Processing Record 32 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 8 | tucuma
# Processing Record 34 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 35 of Set 8 | zyryanka
# Processing Record 36 of Set 8 | bull savanna
# Processing Record 37 of Set 8 | ouallam
# Processing Record 38 of Set 8 | listvyanskiy
# Processing Record 39 of Set 8 | ajuchitlan
# Processing Record 40 of Set 8 | maltahohe
# Processing Record 41 of Set 8 | koslan
# Processing Record 42 of Set 8 | acarau
# Processing Record 43 of Set 8 | broome
# Processing Record 44 of Set 8 | talnakh
# Processing Record 45 of Set 8 | gamba
# Processing Record 46 of Set 8 | lucea
# Processing Record 47 of Set 8 | goure
# Processing Record 48 of Set 8 | road town
# Processing Record 49 of Set 8 | tuskegee
# Processing Record 50 of Set 8 | barra da estiva
# Processing Record 1 of Set 9 | suihua
# Processing Record 2 of Set 9 | nagtipunan
# Processing Record 3 of Set 9 | port macquarie
# Processing Record 4 of Set 9 | severo-kurilsk
# Processing Record 5 of Set 9 | cairns
# Processing Record 6 of Set 9 | victor harbor
# Processing Record 7 of Set 9 | berlevag
# Processing Record 8 of Set 9 | baraboo
# Processing Record 9 of Set 9 | tura
# Processing Record 10 of Set 9 | wattegama
# Processing Record 11 of Set 9 | mwinilunga
# Processing Record 12 of Set 9 | cabimas
# Processing Record 13 of Set 9 | monywa
# Processing Record 14 of Set 9 | lobatse
# Processing Record 15 of Set 9 | tottori
# Processing Record 16 of Set 9 | asosa
# Processing Record 17 of Set 9 | yumen
# Processing Record 18 of Set 9 | alghero
# Processing Record 19 of Set 9 | nome
# Processing Record 20 of Set 9 | deputatskiy
# Processing Record 21 of Set 9 | kaeo
# Processing Record 22 of Set 9 | wichian buri
# Processing Record 23 of Set 9 | shonguy
# Processing Record 24 of Set 9 | mahajanga
# Processing Record 25 of Set 9 | manta
# Processing Record 26 of Set 9 | port hardy
# Processing Record 27 of Set 9 | dzilam gonzalez
# Processing Record 28 of Set 9 | launceston
# Processing Record 29 of Set 9 | coquimbo
# Processing Record 30 of Set 9 | morondava
# Processing Record 31 of Set 9 | ankang
# Processing Record 32 of Set 9 | chenzhou
# Processing Record 33 of Set 9 | yerkoy
# Processing Record 34 of Set 9 | bonfim
# Processing Record 35 of Set 9 | kampot
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | poya
# Processing Record 38 of Set 9 | jishou
# Processing Record 39 of Set 9 | mmabatho
# Processing Record 40 of Set 9 | katsuura
# Processing Record 41 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 42 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 9 | axim
# Processing Record 44 of Set 9 | jijiga
# Processing Record 45 of Set 9 | palauig
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | santiago del estero
# Processing Record 48 of Set 9 | raudeberg
# Processing Record 49 of Set 9 | zorritos
# Processing Record 50 of Set 9 | guarapari
# Processing Record 1 of Set 10 | hualmay
# Processing Record 2 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 10 | gombong
# Processing Record 4 of Set 10 | torbay
# Processing Record 5 of Set 10 | krasnogorskiy
# Processing Record 6 of Set 10 | el reten
# Processing Record 7 of Set 10 | polczyn-zdroj
# Processing Record 8 of Set 10 | sibu
# Processing Record 9 of Set 10 | jucas
# Processing Record 10 of Set 10 | hofn
# Processing Record 11 of Set 10 | constitucion
# Processing Record 12 of Set 10 | brawley
# Processing Record 13 of Set 10 | roseburg
# Processing Record 14 of Set 10 | manacapuru
# Processing Record 15 of Set 10 | hirara
# Processing Record 16 of Set 10 | xingyi
# Processing Record 17 of Set 10 | bongandanga
# Processing Record 18 of Set 10 | kasungu
# Processing Record 19 of Set 10 | mandera
# Processing Record 20 of Set 10 | vreed en hoop
# City not found. Skipping...
# Processing Record 21 of Set 10 | camacupa
# Processing Record 22 of Set 10 | ejido hermosillo
# Processing Record 23 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 10 | barcelos
# Processing Record 25 of Set 10 | san joaquin
# Processing Record 26 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 10 | mapiripan
# Processing Record 28 of Set 10 | ugoofaaru
# Processing Record 29 of Set 10 | decatur
# Processing Record 30 of Set 10 | glens falls
# Processing Record 31 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 10 | pinega
# Processing Record 33 of Set 10 | chifeng
# Processing Record 34 of Set 10 | portsmouth
# Processing Record 35 of Set 10 | el faiyum
# City not found. Skipping...
# Processing Record 36 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 37 of Set 10 | zavodoukovsk
# Processing Record 38 of Set 10 | kamsack
# Processing Record 39 of Set 10 | hithadhoo
# Processing Record 40 of Set 10 | gobabis
# Processing Record 41 of Set 10 | mundo nuevo
# Processing Record 42 of Set 10 | sakakah
# Processing Record 43 of Set 10 | waingapu
# Processing Record 44 of Set 10 | dalianwan
# Processing Record 45 of Set 10 | tiblawan
# Processing Record 46 of Set 10 | maykor
# Processing Record 47 of Set 10 | puerto escondido
# Processing Record 48 of Set 10 | flin flon
# Processing Record 49 of Set 10 | locri
# Processing Record 50 of Set 10 | zhoucun
# Processing Record 1 of Set 11 | dzerzhinsk
# Processing Record 2 of Set 11 | shache
# Processing Record 3 of Set 11 | kalevala
# Processing Record 4 of Set 11 | mayor pablo lagerenza
# Processing Record 5 of Set 11 | karratha
# Processing Record 6 of Set 11 | puerto leguizamo
# Processing Record 7 of Set 11 | aksu
# Processing Record 8 of Set 11 | sao filipe
# Processing Record 9 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 11 | sanhsia
# City not found. Skipping...
# Processing Record 11 of Set 11 | port moresby
# Processing Record 12 of Set 11 | ende
# Processing Record 13 of Set 11 | lompoc
# Processing Record 14 of Set 11 | grande-riviere
# City not found. Skipping...
# Processing Record 15 of Set 11 | olinda
# Processing Record 16 of Set 11 | saint-augustin
# Processing Record 17 of Set 11 | vezirkopru
# Processing Record 18 of Set 11 | general roca
# Processing Record 19 of Set 11 | dabat
# Processing Record 20 of Set 11 | lindas
# Processing Record 21 of Set 11 | touros
# Processing Record 22 of Set 11 | gimli
# Processing Record 23 of Set 11 | arica
# Processing Record 24 of Set 11 | sao joao da barra
# Processing Record 25 of Set 11 | novikovo
# Processing Record 26 of Set 11 | roma
# Processing Record 27 of Set 11 | yarovoye
# Processing Record 28 of Set 11 | northam
# Processing Record 29 of Set 11 | kapit
# Processing Record 30 of Set 11 | bage
# Processing Record 31 of Set 11 | tuscaloosa
# Processing Record 32 of Set 11 | sochi
# Processing Record 33 of Set 11 | monrovia
# Processing Record 34 of Set 11 | gore
# Processing Record 35 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 36 of Set 11 | promyshlennaya
# Processing Record 37 of Set 11 | narrabri
# Processing Record 38 of Set 11 | bereda
# Processing Record 39 of Set 11 | mnogovershinnyy
# Processing Record 40 of Set 11 | hwange
# Processing Record 41 of Set 11 | palasa
# Processing Record 42 of Set 11 | bokhan
# Processing Record 43 of Set 11 | port stanley
# Processing Record 44 of Set 11 | dano
# Processing Record 45 of Set 11 | huandacareo
# Processing Record 46 of Set 11 | labelle
# Processing Record 47 of Set 11 | makakilo city
# Processing Record 48 of Set 11 | colombia
# Processing Record 49 of Set 11 | oistins
# Processing Record 50 of Set 11 | aklavik
# Processing Record 1 of Set 12 | dongsheng
# Processing Record 2 of Set 12 | kyren
# Processing Record 3 of Set 12 | lokosovo
# Processing Record 4 of Set 12 | phonhong
# Processing Record 5 of Set 12 | farafangana
# Processing Record 6 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 12 | solsvik
# City not found. Skipping...
# Processing Record 8 of Set 12 | caravelas
# Processing Record 9 of Set 12 | adeje
# Processing Record 10 of Set 12 | chandbali
# Processing Record 11 of Set 12 | samarai
# Processing Record 12 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 12 | banos
# Processing Record 14 of Set 12 | schwarzenbek
# Processing Record 15 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 16 of Set 12 | villacarrillo
# Processing Record 17 of Set 12 | anadyr
# Processing Record 18 of Set 12 | amnat charoen
# Processing Record 19 of Set 12 | taylorville
# Processing Record 20 of Set 12 | sivac
# Processing Record 21 of Set 12 | carlsbad
# Processing Record 22 of Set 12 | benalla
# Processing Record 23 of Set 12 | los llanos de aridane
# Processing Record 24 of Set 12 | port augusta
# Processing Record 25 of Set 12 | batemans bay
# Processing Record 26 of Set 12 | teya
# Processing Record 27 of Set 12 | chaplygin
# Processing Record 28 of Set 12 | kurunegala
# Processing Record 29 of Set 12 | zuenoula
# Processing Record 30 of Set 12 | nizhniy kuranakh
# Processing Record 31 of Set 12 | morrovalle
# Processing Record 32 of Set 12 | barstow
# Processing Record 33 of Set 12 | romny
# Processing Record 34 of Set 12 | abha
# Processing Record 35 of Set 12 | solone
# Processing Record 36 of Set 12 | razole
# Processing Record 37 of Set 12 | griffith
# Processing Record 38 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 39 of Set 12 | neuquen
# Processing Record 40 of Set 12 | bilibino
# Processing Record 41 of Set 12 | puerto del rosario
# Processing Record 42 of Set 12 | charagua
# Processing Record 43 of Set 12 | am timan
# Processing Record 44 of Set 12 | santander
# Processing Record 45 of Set 12 | saint-georges
# Processing Record 46 of Set 12 | anloga
# Processing Record 47 of Set 12 | pandan
# Processing Record 48 of Set 12 | trairi
# Processing Record 49 of Set 12 | foligno
# Processing Record 50 of Set 12 | makat
# Processing Record 1 of Set 13 | vermillion
# Processing Record 2 of Set 13 | flinders
# Processing Record 3 of Set 13 | popondetta
# Processing Record 4 of Set 13 | boguchany
# Processing Record 5 of Set 13 | tanout
# Processing Record 6 of Set 13 | orsk
# Processing Record 7 of Set 13 | tondano
# Processing Record 8 of Set 13 | konstantinovka
# Processing Record 9 of Set 13 | vila velha
# Processing Record 10 of Set 13 | manggar
# Processing Record 11 of Set 13 | gambela
# Processing Record 12 of Set 13 | batetskiy
# Processing Record 13 of Set 13 | lerwick
# Processing Record 14 of Set 13 | eastbourne
# Processing Record 15 of Set 13 | vila do maio
# Processing Record 16 of Set 13 | rozivka
# Processing Record 17 of Set 13 | varkaus
# Processing Record 18 of Set 13 | ponta delgada
# Processing Record 19 of Set 13 | inuvik
# Processing Record 20 of Set 13 | almaznyy
# Processing Record 21 of Set 13 | talas
# Processing Record 22 of Set 13 | ntoum
# Processing Record 23 of Set 13 | asfi
# Processing Record 24 of Set 13 | high level
# Processing Record 25 of Set 13 | lumphat
# Processing Record 26 of Set 13 | erzin
# Processing Record 27 of Set 13 | valjala
# City not found. Skipping...
# Processing Record 28 of Set 13 | abulug
# Processing Record 29 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 30 of Set 13 | garhakota
# Processing Record 31 of Set 13 | vila franca do campo
# Processing Record 32 of Set 13 | tamandare
# Processing Record 33 of Set 13 | port-gentil
# Processing Record 34 of Set 13 | tromso
# Processing Record 35 of Set 13 | ormara
# Processing Record 36 of Set 13 | effingham
# Processing Record 37 of Set 13 | wajima
# Processing Record 38 of Set 13 | altay
# Processing Record 39 of Set 13 | chengde
# Processing Record 40 of Set 13 | seymchan
# Processing Record 41 of Set 13 | anshun
# Processing Record 42 of Set 13 | kruisfontein
# Processing Record 43 of Set 13 | ziro
# Processing Record 44 of Set 13 | grand-santi
# Processing Record 45 of Set 13 | angoche
# Processing Record 46 of Set 13 | toro
# Processing Record 47 of Set 13 | grants
# Processing Record 48 of Set 13 | atbasar
# Processing Record 49 of Set 13 | soanierana ivongo
# Processing Record 50 of Set 13 | shitanjing
# Processing Record 1 of Set 14 | torit
# Processing Record 2 of Set 14 | altamira
# Processing Record 3 of Set 14 | dengfeng
# Processing Record 4 of Set 14 | rock sound
# Processing Record 5 of Set 14 | imeni babushkina
# Processing Record 6 of Set 14 | malangwa
# Processing Record 7 of Set 14 | el sauzal
# Processing Record 8 of Set 14 | biak
# Processing Record 9 of Set 14 | tautira
# Processing Record 10 of Set 14 | auki
# Processing Record 11 of Set 14 | fort nelson
# Processing Record 12 of Set 14 | formosa do rio preto
# Processing Record 13 of Set 14 | ivaipora
# Processing Record 14 of Set 14 | hay river
# Processing Record 15 of Set 14 | kidal
# Processing Record 16 of Set 14 | nova olinda do norte
# Processing Record 17 of Set 14 | ambon
# Processing Record 18 of Set 14 | labuhan
# Processing Record 19 of Set 14 | inisa
# Processing Record 20 of Set 14 | kibre mengist
# Processing Record 21 of Set 14 | havelock
# Processing Record 22 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 23 of Set 14 | port blair
# Processing Record 24 of Set 14 | kamenka
# Processing Record 25 of Set 14 | paris
# Processing Record 26 of Set 14 | acari
# Processing Record 27 of Set 14 | sao felix do xingu
# Processing Record 28 of Set 14 | ketchikan
# Processing Record 29 of Set 14 | outram
# Processing Record 30 of Set 14 | ofaqim
# Processing Record 31 of Set 14 | tete
# Processing Record 32 of Set 14 | baker city
# Processing Record 33 of Set 14 | harper
# Processing Record 34 of Set 14 | seoul
# Processing Record 35 of Set 14 | kirakira
# Processing Record 36 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 14 | coahuayana
# Processing Record 38 of Set 14 | urumqi
# Processing Record 39 of Set 14 | kon tum
# Processing Record 40 of Set 14 | aitape
# Processing Record 41 of Set 14 | katangli
# Processing Record 42 of Set 14 | ahipara
# Processing Record 43 of Set 14 | glyadyanskoye
# Processing Record 44 of Set 14 | sakaiminato
# Processing Record 45 of Set 14 | valparaiso
# Processing Record 46 of Set 14 | albi
# Processing Record 47 of Set 14 | champerico
# Processing Record 48 of Set 14 | torrington
# Processing Record 49 of Set 14 | gorontalo
# Processing Record 50 of Set 14 | malanje
# Processing Record 1 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 15 | saint-pierre
# Processing Record 3 of Set 15 | itaqui
# Processing Record 4 of Set 15 | salalah
# Processing Record 5 of Set 15 | faya
# Processing Record 6 of Set 15 | trail
# Processing Record 7 of Set 15 | san policarpo
# Processing Record 8 of Set 15 | shatsk
# Processing Record 9 of Set 15 | goksun
# Processing Record 10 of Set 15 | sestri levante
# Processing Record 11 of Set 15 | martil
# Processing Record 12 of Set 15 | petukhovo
# Processing Record 13 of Set 15 | rawah
# Processing Record 14 of Set 15 | esil
# Processing Record 15 of Set 15 | codrington
# Processing Record 16 of Set 15 | zvenyhorodka
# Processing Record 17 of Set 15 | rexburg
# Processing Record 18 of Set 15 | brufut
# Processing Record 19 of Set 15 | yantikovo
# Processing Record 20 of Set 15 | urusha
# Processing Record 21 of Set 15 | lixourion
# Processing Record 22 of Set 15 | bisho
# Processing Record 23 of Set 15 | ukiah
# Processing Record 24 of Set 15 | jacareacanga
# Processing Record 25 of Set 15 | olavarria
# Processing Record 26 of Set 15 | portland
# Processing Record 27 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 28 of Set 15 | goes
# Processing Record 29 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 15 | dimbokro
# Processing Record 31 of Set 15 | ostrovnoy
# Processing Record 32 of Set 15 | lakhdenpokhya
# Processing Record 33 of Set 15 | chandler
# Processing Record 34 of Set 15 | omsukchan
# Processing Record 35 of Set 15 | gizo
# Processing Record 36 of Set 15 | hongjiang
# Processing Record 37 of Set 15 | simpang
# Processing Record 38 of Set 15 | te anau
# Processing Record 39 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 40 of Set 15 | taltal
# Processing Record 41 of Set 15 | mackay
# Processing Record 42 of Set 15 | ocampo
# Processing Record 43 of Set 15 | sal rei
# Processing Record 44 of Set 15 | whitianga
# Processing Record 45 of Set 15 | cazaje
# City not found. Skipping...
# Processing Record 46 of Set 15 | odda
# Processing Record 47 of Set 15 | petropavlovka
# Processing Record 48 of Set 15 | constantine
# Processing Record 49 of Set 15 | lichuan
# Processing Record 50 of Set 15 | soyo
# Processing Record 1 of Set 16 | camacha
# Processing Record 2 of Set 16 | agadir
# Processing Record 3 of Set 16 | guaira
# Processing Record 4 of Set 16 | biu
# Processing Record 5 of Set 16 | ulmu
# Processing Record 6 of Set 16 | dustlik
# Processing Record 7 of Set 16 | grove city
# Processing Record 8 of Set 16 | hobyo
# Processing Record 9 of Set 16 | charters towers
# Processing Record 10 of Set 16 | coolum beach
# Processing Record 11 of Set 16 | la primavera
# Processing Record 12 of Set 16 | calama
# Processing Record 13 of Set 16 | oktyabrskiy
# Processing Record 14 of Set 16 | abu jubayhah
# City not found. Skipping...
# Processing Record 15 of Set 16 | naxos
# Processing Record 16 of Set 16 | jaque
# Processing Record 17 of Set 16 | mabama
# Processing Record 18 of Set 16 | sand
# Processing Record 19 of Set 16 | chuncheng
# Processing Record 20 of Set 16 | aldan
# Processing Record 21 of Set 16 | santa cruz
# Processing Record 22 of Set 16 | conde
# Processing Record 23 of Set 16 | sur
# Processing Record 24 of Set 16 | rocha
# Processing Record 25 of Set 16 | kutum
# Processing Record 26 of Set 16 | jardim de piranhas
# Processing Record 27 of Set 16 | lagoa
# Processing Record 28 of Set 16 | nha trang
# Processing Record 29 of Set 16 | gornopravdinsk
# Processing Record 30 of Set 16 | sioux lookout
# Processing Record 31 of Set 16 | omboue
# Processing Record 32 of Set 16 | neiafu
# Processing Record 33 of Set 16 | bara
# Processing Record 34 of Set 16 | salamiyah
# Processing Record 35 of Set 16 | pringsewu
# Processing Record 36 of Set 16 | rundu
# Processing Record 37 of Set 16 | toba
# Processing Record 38 of Set 16 | grindavik
# Processing Record 39 of Set 16 | kathu
# Processing Record 40 of Set 16 | pacific grove
# Processing Record 41 of Set 16 | ipixuna
# Processing Record 42 of Set 16 | minsk
# Processing Record 43 of Set 16 | puerto maldonado
# Processing Record 44 of Set 16 | samfya
# Processing Record 45 of Set 16 | adrar
# Processing Record 46 of Set 16 | nanortalik
# Processing Record 47 of Set 16 | shenjiamen
# Processing Record 48 of Set 16 | yate
# Processing Record 49 of Set 16 | beatrice
# Processing Record 50 of Set 16 | batagay-alyta
# Processing Record 1 of Set 17 | natchitoches
# Processing Record 2 of Set 17 | thinadhoo
# Processing Record 3 of Set 17 | scottsburgh
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 742

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  New Norfolk -42.78  147.06     69.80        52          75       18.34
# 1       Avarua -21.21 -159.78     75.20        83         100        9.17
# 2      Ushuaia -54.80  -68.30     51.80        57          40       13.87
# 3      Mataura -46.19  168.86     77.00        41           4        6.53
# 4  Tuktoyaktuk  69.45 -133.04     12.20        85          90        9.17
# 5    Dovolnoye  54.50   79.67     29.07        93         100       10.04
# 6       Palmer  42.16  -72.33     28.99        79          20        0.89
# 7  East London -33.02   27.91     67.44        88          37        3.06
# 8        Buala  -8.14  159.59     86.16        66          78        6.93
# 9        Vaini -21.20 -175.20     80.60        78          40       13.87
#
#   Current Description Country
# 0       broken clouds      AU
# 1     overcast clouds      CK
# 2    scattered clouds      AR
# 3           clear sky      NZ
# 4          light snow      CA
# 5     overcast clouds      RU
# 6          few clouds      US
# 7    scattered clouds      ZA
# 8          light rain      SB
# 9    scattered clouds      TO

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  New Norfolk      AU -42.78  147.06      69.8        52          75
# 1       Avarua      CK -21.21 -159.78      75.2        83         100
# 2      Ushuaia      AR -54.80  -68.30      51.8        57          40
# 3      Mataura      NZ -46.19  168.86      77.0        41           4
# 4  Tuktoyaktuk      CA  69.45 -133.04      12.2        85          90
#
#    Wind Speed Current Description
# 0       18.34       broken clouds
# 1        9.17     overcast clouds
# 2       13.87    scattered clouds
# 3        6.53           clear sky
# 4        9.17          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
